# %%
from sklearn import svm, datasets
from sklearn.model_selection import cross_val_score
X, y = datasets.load_iris(return_X_y=True)
clf = svm.SVC(random_state=0, kernel='linear')
scores = cross_val_score(clf, X, y, cv=5, scoring='recall_macro')

# %%
clf.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-eaad8d6955f1> in <module>
# ----> 1 clf.coef_
#
# ~/anaconda3/envs/mne/lib/python3.6/site-packages/sklearn/svm/_base.py in coef_(self)
#     493                                  'linear kernel')
#     494
# --> 495         coef = self._get_coef()
#     496
#     497         # coef_ being a read-only property, it's better to mark the value as
#
# ~/anaconda3/envs/mne/lib/python3.6/site-packages/sklearn/svm/_base.py in _get_coef(self)
#     741
#     742     def _get_coef(self):
# --> 743         if self.dual_coef_.shape[0] == 1:
#     744             # binary classifier
#     745             coef = safe_sparse_dot(self.dual_coef_, self.support_vectors_)
#
# AttributeError: 'SVC' object has no attribute 'dual_coef_'
