# %%
# pipeline Encoding model
import numpy as np
import pandas as pd
import sys
sys.path.append('/Users/pinheirochagas/Pedro/Stanford/code/lbcn_encoding_decoding/functions/')
import encoding_functions
from sklearn.preprocessing import scale
from sklearn.metrics import r2_score
import sys
from sklearn import cross_validation as cv

# %%
## Import list of subjects
data_dir = '/Volumes/LBCN8T_2/Stanford/data/encoding/raw/VTCLoc/'
subject_number = '132'

# Load stim features
stim = load_stim_features(data_dir, subject_number)
# Load brain features
brain = load_brain_features(data_dir, subject_number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c2e51e9b00b4> in <module>()
#       4
#       5 # Load stim features
# ----> 6 stim = load_stim_features(data_dir, subject_number)
#       7 # Load brain features
#       8 brain = load_brain_features(data_dir, subject_number)
#
# NameError: name 'load_stim_features' is not defined

# %%
import encoding_functions
